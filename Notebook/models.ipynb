# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
print('Imported')
# Out:
# Imported

# %%
df = pd.read_csv('Dataset/Network-flows.csv')

# %%
df.head()
# Out:
#                            flow_key  src_ip_numeric         src_ip  src_port  \
# 0  3acee4f4ea001cd5e6d9584d4036b53d      3232266497  192.168.121.1        67
# 1  974ec5991b439c9a7176b88be0c90df0      3232266497  192.168.121.1        67
# 2  3acee4f4ea001cd5e6d9584d4036b53d      3232266497  192.168.121.1        67
# 3  974ec5991b439c9a7176b88be0c90df0      3232266497  192.168.121.1        67
# 4  cfa7c2740072befaa89c202499729e08      3232266497  192.168.121.1         0
#
#            dst_ip  dst_port  proto  pktTotalCount  octetTotalCount  min_ps  \
# 0  172.16.255.185        67     17             22             7620     328
# 1  172.16.255.186        67     17             17             5670     328
# 2  172.16.255.185        67     17             43            15124     328
# 3  172.16.255.186        67     17             30            10086     328
# 4    10.130.1.166         0      1              1               56      56
#
# ...

# %%
df.shape
# Out:
# (2704839, 50)

# %%
df = df.sample(int(df.shape[0]*0.20))

# %%
df.shape
# Out:
# (540967, 50)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 540967 entries, 2293372 to 2637619
# Data columns (total 50 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   flow_key              540967 non-null  object
#  1   src_ip_numeric        540967 non-null  int64
#  2   src_ip                540967 non-null  object
#  3   src_port              540967 non-null  int64
#  4   dst_ip                540967 non-null  object
#  5   dst_port              540967 non-null  int64
#  6   proto                 540967 non-null  int64
#  7   pktTotalCount         540967 non-null  int64
#  8   octetTotalCount       540967 non-null  int64
#  9   min_ps                540967 non-null  int64
#  10  max_ps                540967 non-null  int64
#  11  avg_ps                540967 non-null  float64
#  12  std_dev_ps            540967 non-null  float64
#  13  flowStart             540967 non-null  float64
# ...

# %%
df.describe()
# Out:
#        src_ip_numeric       src_port       dst_port          proto  \
# count    5.409670e+05  540967.000000  540967.000000  540967.000000
# mean     3.232268e+09   51143.152336    2743.699895      10.809027
# std      7.158883e+02   13160.362441    9220.563727       5.476596
# min      3.232266e+09       0.000000       0.000000       1.000000
# 25%      3.232267e+09   49776.000000      53.000000       6.000000
# 50%      3.232268e+09   53250.000000     443.000000       6.000000
# 75%      3.232268e+09   58986.000000     443.000000      17.000000
# max      3.232269e+09   65535.000000   65535.000000      17.000000
#
#        pktTotalCount  octetTotalCount         min_ps         max_ps  \
# count  540967.000000     5.409670e+05  540967.000000  540967.000000
# mean       91.436598     1.106504e+05      58.155573    1254.063505
# std      3857.500751     5.745742e+06      59.849716    2942.825783
# min         1.000000     2.900000e+01      28.000000      28.000000
# ...

# %%
num_cols = [x for x in df.columns if df[x].dtype != 'object']
cat_cols = [x for x in df.columns if df[x].dtype == 'object']

# %%
print(f'Number of numerical columns = {len(num_cols)}')
print(f'Number of categorical columns = {len(cat_cols)}')
# Out:
# Number of numerical columns = 44
# Number of categorical columns = 6

# %% [markdown]
# ## Categorical Columns

# %%
df.head(2)
# Out:
#                                  flow_key  src_ip_numeric          src_ip  \
# 2293372  4f6cce9c3e35c5de3bfb8049c1324e28      3232268111  192.168.127.79
# 1078864  a12c8ebecca9e5490589b061c67ab990      3232268291   192.168.128.3
#
#          src_port         dst_ip  dst_port  proto  pktTotalCount  \
# 2293372     56847  172.217.28.99       443      6             14
# 1078864     34228  190.90.252.32       443      6              8
#
#          octetTotalCount  min_ps  max_ps      avg_ps  std_dev_ps  \
# 2293372             4918      40    1458  351.285714  519.438354
# 1078864             1304      52     536  163.000000  189.195666
#
#             flowStart       flowEnd  flowDuration  min_piat   max_piat  \
# 2293372  1.559692e+09  1.559692e+09      0.109813  0.000004   0.096580
# 1078864  1.556138e+09  1.556138e+09     16.091929  0.000032  15.958746
#
#          avg_piat  std_dev_piat  f_pktTotalCount  f_octetTotalCount  f_min_ps  \
# ...

# %%
df['category'].value_counts(), df['category'].nunique()
# Out:
# (Web                                  283735
#  Network                               88149
#  Unspecified                           49758
#  SocialNetwork                         30292
#  Chat                                  15204
#  Download-FileTransfer-FileSharing     14218
#  Media                                 12708
#  Cloud                                 10005
#  VoIP                                   9475
#  Collaborative                          7819
#  System                                 7242
#  Email                                  4574
#  SoftwareUpdate                         3221
#  Video                                  1652
#  Music                                   742
#  RemoteAccess                            691
#  Game                                    565
#  RPC                                     432
#  Database                                170
#  Streaming                               136
#  VPN                                      98
# ...

# %%
df['application_protocol'].value_counts(), df['application_protocol'].nunique()
# Out:
# (Unknown         261345
#  TLS             138591
#  DNS              98099
#  HTTP             25534
#  QUIC             14220
#  STUN              2651
#  IMAPS              366
#  Skype               67
#  SMTPS               38
#  POPS                34
#  HTTP_Proxy           7
#  PostgreSQL           4
#  BitTorrent           3
#  NetBIOS              2
#  Git                  2
#  MQTT                 1
#  FacebookZero         1
#  SMTP                 1
#  SMBv23               1
#  Name: application_protocol, dtype: int64,
#  19)

# %%
df['web_service'].value_counts(), df['web_service'].nunique()
# Out:
# (Google        113818
#  DNS            83543
#  TLS            52276
#  Unknown        49758
#  Microsoft      34486
#                 ...
#  PostgreSQL         1
#  Tuenti             1
#  MySQL              1
#  DNP3               1
#  GTP                1
#  Name: web_service, Length: 130, dtype: int64,
#  130)

# %%
df.head(1)
# Out:
#                                  flow_key  src_ip_numeric          src_ip  \
# 2293372  4f6cce9c3e35c5de3bfb8049c1324e28      3232268111  192.168.127.79
#
#          src_port         dst_ip  dst_port  proto  pktTotalCount  \
# 2293372     56847  172.217.28.99       443      6             14
#
#          octetTotalCount  min_ps  max_ps      avg_ps  std_dev_ps  \
# 2293372             4918      40    1458  351.285714  519.438354
#
#             flowStart       flowEnd  flowDuration  min_piat  max_piat  \
# 2293372  1.559692e+09  1.559692e+09      0.109813  0.000004   0.09658
#
#          avg_piat  std_dev_piat  f_pktTotalCount  f_octetTotalCount  f_min_ps  \
# 2293372  0.008447      0.025553                7                873        40
#
#          f_max_ps    f_avg_ps  f_std_dev_ps   f_flowStart     f_flowEnd  \
# 2293372       557  124.714286    177.801426  1.559692e+09  1.559692e+12
#
#          f_flowDuration  f_min_piat  f_max_piat  f_avg_piat  f_std_dev_piat  \
# ...

# %%
df['flow_key'].nunique(), df['dst_port'].nunique(), df['src_ip'].nunique()
# Out:
# (520225, 16245, 715)

# %% [markdown]
# ##### as we can see flow_key as unique identities as many as logged credentials, so we do not need that, but the other are repeatative values, and they could be helpfull for us.

# %% [markdown]
# ### Numerical Columns

# %%
df[num_cols].head(2)
# Out:
#          src_ip_numeric  src_port  dst_port  proto  pktTotalCount  \
# 2293372      3232268111     56847       443      6             14
# 1078864      3232268291     34228       443      6              8
#
#          octetTotalCount  min_ps  max_ps      avg_ps  std_dev_ps  \
# 2293372             4918      40    1458  351.285714  519.438354
# 1078864             1304      52     536  163.000000  189.195666
#
#             flowStart       flowEnd  flowDuration  min_piat   max_piat  \
# 2293372  1.559692e+09  1.559692e+09      0.109813  0.000004   0.096580
# 1078864  1.556138e+09  1.556138e+09     16.091929  0.000032  15.958746
#
#          avg_piat  std_dev_piat  f_pktTotalCount  f_octetTotalCount  f_min_ps  \
# 2293372  0.008447      0.025553                7                873        40
# 1078864  2.298847      5.576818                4               1088        52
#
#          f_max_ps    f_avg_ps  f_std_dev_ps   f_flowStart     f_flowEnd  \
# ...

# %%
## lets check the uniqueness in numerical columns as well
for cols in num_cols:
    if df[cols].nunique() > df.shape[0]*0.10:
        print(f'{cols}  --------->    {df[cols].nunique()}')
